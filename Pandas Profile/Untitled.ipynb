# %% [markdown]
# # Pandas Profiling

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /home/babbar/miniconda3/lib/python3.13/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (2.13.2)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (2.33.1)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /home/babbar/miniconda3/lib/python3.13/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /home/babbar/miniconda3/lib/python3.13/site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /home/babbar/miniconda3/lib/python3.13/site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/babbar/miniconda3/lib/python3.13/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/babbar/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/babbar/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/babbar/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.5.20)
# Requirement already satisfied: patsy>=0.5.6 in /home/babbar/miniconda3/lib/python3.13/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/babbar/miniconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in /home/babbar/miniconda3/lib/python3.13/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/babbar/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
# !pip install --upgrade setuptools wheel
# Out:
# Requirement already satisfied: setuptools in /home/babbar/miniconda3/lib/python3.13/site-packages (81.0.0)
# Collecting setuptools
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /home/babbar/miniconda3/lib/python3.13/site-packages (0.47.0)
# Requirement already satisfied: packaging>=24.0 in /home/babbar/miniconda3/lib/python3.13/site-packages (from wheel) (26.2)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 81.0.0
#     Uninstalling setuptools-81.0.0:
#       Successfully uninstalled setuptools-81.0.0
# Successfully installed setuptools-82.0.1

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas_profiling/__init__.py:8
#       5 import importlib.util
#       6 from warnings import warn
# ----> 8 from ydata_profiling.compare_reports import compare
#       9 from ydata_profiling.controller import pandas_decorator
#      10 from ydata_profiling.profile_report import ProfileReport
#
# File ~/miniconda3/lib/python3.13/site-packages/ydata_profiling/__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from data_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from data_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from data_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/miniconda3/lib/python3.13/site-packages/data_profiling/__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from data_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from data_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from data_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/miniconda3/lib/python3.13/site-packages/data_profiling/compare_reports.py:12
#      10 from data_profiling.model import BaseDescription
#      11 from data_profiling.model.alerts import Alert
# ---> 12 from data_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/miniconda3/lib/python3.13/site-packages/data_profiling/profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
# !pip install setuptools
# Out:
# Requirement already satisfied: setuptools in /home/babbar/miniconda3/lib/python3.13/site-packages (82.0.1)

# %%
# %pip install "setuptools<82"
# Out:
# Collecting setuptools<82
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
# Successfully installed setuptools-81.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pkg_resources
print(f"pkg_resources version: {pkg_resources.get_distribution('setuptools').version}")
# Out:
# pkg_resources version: 81.0.0
# /tmp/ipykernel_48813/54270529.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import importlib.metadata

version = importlib.metadata.version('setuptools')
print(f"setuptools version: {version}")
# Out:
# setuptools version: 81.0.0

# %%
from pandas_profiling import ProfileReport

# %%
prof = ProfileReport(df)

# %%
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:  41%|███████████████████████████████████████████▏                                                             | 7/17 [00:00<00:00, 68.13it/s, Describe variable: Embarked]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 565.27it/s]
# Summarize dataset: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:01<00:00, 29.79it/s, Completed]
# Generate report structure: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.86s/it]
# Render HTML: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.97it/s]
# Export report to file: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 207.23it/s]
