# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 7.9 MB/s  0:00:01a 0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 11.7 MB/s  0:00:01 eta 0:00:0136m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# ...

# %% [markdown]
# ## Extract JSON Date form the URL

# %%
pd.read_json("url")

# %% [markdown]
# ## Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 9.7 MB/s  0:00:019.7 MB/s eta 0:00:0102
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp313-cp313-linux_x86_64.whl size=248042 sha256=30d682b27fb398123ca77b57a4ef7d2468d3d5d5a0dd0a6db72428bdca9672fc
#   Stored in directory: /home/babbar/.cache/pip/wheels/4e/c1/23/9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

conn = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='',
    database='world'
)

print("Connected!")
# Out:
# Connected!

# %%
df = pd.read_sql_query("SELECT * FROM city", conn)
print(df.head())
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200
# /tmp/ipykernel_56432/3735645751.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM city", conn)
